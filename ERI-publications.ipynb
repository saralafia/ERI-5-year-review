# %%
# Read in csv of ERI PIs (2014-2019) to dataframe
import pandas as pd
df = pd.read_csv('people/PI.csv',index_col=False)
#df.head()

# %%
# Read in Researcher (name, university) and Name (name) columns to separate lists
researchers = df['Researcher'].tolist()
names = df['Name'].tolist()

# %%
# Import and test that scholarly package returns a generator of Author objects
import scholarly
print(next(scholarly.search_author(researchers[129])))
# Out:
# {'_filled': False,
#  'affiliation': 'UC Santa Barbara, Bren School of Environmental Science and '
#                 'Management & Department …',
#  'citedby': 6207,
#  'email': '@ucsb.edu',
#  'id': 'VGaoB64AAAAJ',
#  'interests': ['Ecohydrology',
#                'Environmental Sciences',
#                'Ecology',
#                'Hydrology',
#                'Water Resources'],
#  'name': 'Kelly Caylor',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=VGaoB64AAAAJ'}

# %%
# Retrieve author identifier and keywords (takes several minutes to run)
identifier = []
interests = []
for PI in researchers:
    author = next(scholarly.search_author(PI),None)
    if author is None:
        print("Error %s not found" %PI)
        identifier.append("none")
        interests.append("none")
    else:
        #print(author.id)
        #print(author.interests)
        identifier.append(author.id)
        interests.append(author.interests)
# Out:
# RCP0c0kAAAAJ
# ['environmental politics', 'legislative politics', 'wildfire']
# RzT0j3EAAAAJ
# ['environmental politics', 'governance', 'foreign aid', 'international organizations', 'accountability']
# BV2TtRkAAAAJ
# ['environmental economics', 'climate change', 'political economy']
# 38CdyQoAAAAJ
# ['Natural resource economics', 'fisheries', 'uncertainty']
# FgUUzKkAAAAJ
# ['Frank W Davis']
# xf0GIdEAAAAJ
# ['Jeff Dozier']
# C1BC1sIAAAAJ
# ['Tom Dunne']
# nxF4XdQAAAAJ
# ['environmental informatics']
# L_VT3-cAAAAJ
# ['Conservation Biology', 'Marine Ecology']
# YhCLK5kAAAAJ
# ['Roland Geyer']
# 6XVuz14AAAAJ
# ['Marine ecology', 'conservation biology']
# UgmA89cAAAAJ
# ['Water Quality', 'Soil Processes', 'Pollution']
# RaYb-oMAAAAJ
# ['Microeconomics', 'Field Experiments', 'Environmental Economics', 'Development Economics']
# 9lzSDgcAAAAJ
# ['water resources', 'large data', 'geochemistry', 'hydrology', 'global change']
# zXQpymQAAAAJ
# ['Environment', 'Water Resources Management']
# sD8YzJgAAAAJ
# ['Theoretical Ecology', 'Conservation Biology', 'Population Ecology', 'Fisheries Management']
# jycJQRMAAAAJ
# ['Sustainable agriculture', 'Ecology', 'Global change', 'Land use', 'Applied econometrics']
# i7R7100AAAAJ
# ['Applied Marine Ecology and Fisheries …']
# SxcotMcAAAAJ
# ['Gary Libecap']
# Vvo98qYAAAAJ
# ['Limnology']
# mmfntE0AAAAJ
# ['Environmental economics']
# mruBPJUAAAAJ
# ['Matthew Potoski']
# qD5L-u0AAAAJ
# ['environmental law', 'environmental policy', 'environmental economics']
# y_uuPP0AAAAJ
# ['Industrial Ecology', 'Life Cycle Assessment', 'Sustainability']
# YqRA7csAAAAJ
# ['Hydrology', 'Ecosystems', 'Modeling', 'Informatics', 'Biogeochemical Cycling']
# xlfT8vcAAAAJ
# ['ecology', 'sustainability', 'biodiversity', 'diet-health', 'agriculture']
# 9t14TKcAAAAJ
# ['Galen Stucky']
# Vj8zKdEAAAAJ
# ['Seismology']
# Error Stanley Awramik UCSB not found
# Y_DNpx4AAAAJ
# ['Douglas Burbank']
# Error Cathy Busby UCSB not found
# 4UIEFcIAAAAJ
# ['geochemistry', 'geology', 'hydrology', 'oceanography']
# xeUMyxAAAAAJ
# ['Earth science', 'geochronology', 'tectonics']
# zFDhf6MAAAAJ
# ['Geophysics', 'Seismology', 'Tectonics', 'Inverse Theory', 'Earth Science']
# m7tnZn8AAAAJ
# ['Structural Geology', 'Tectonics', 'Volcanology', 'Geochronology', 'Ore Deposits']
# KSvF4pEAAAAJ
# ['geochronology', 'metamorphic petrology', 'tectonics', 'petrochronology', 'metamorphic geology']
# dDNiAwEAAAAJ
# ['Geochemistry', 'Geology']
# M0ZSdNUAAAAJ
# ['Earthquake Seismology']
# MlDIrsgAAAAJ
# ['Earth Surface Processes', 'Environmental Geology']
# lto7l1kAAAAJ
# ['Climate Change', 'Paleoceanography', 'Geochemistry', 'Paleoclimate']
# McNJSi4AAAAJ
# ['paleoclimate', 'paleoceanography', 'glacial cycles']
# fLRRRrcAAAAJ
# ['Geology']
# HNKEI3MAAAAJ
# ['Geophysics', 'Volcanology', 'Seismology', 'Acoustics', 'Infrasound']
# d5_TSk8AAAAJ
# ['Geology', 'Active tectonics', 'tectonic geomorphology', 'landscape evolution']
# O_Fcmwy21PIC
# ['Paleobiology']
# KtVrxIcAAAAJ
# ['Sulfur biogeochemistry', 'carbon cycling', 'geobiology']
# ocbjavsAAAAJ
# ['Geology', 'Geochemistry', 'Geophysics', 'Lithium Isotopes']
# 1pt8QIsAAAAJ
# ['Sedimentology', 'Coastal Geology', 'Quaternary Science', 'Antarctica']
# E3cCohYAAAAJ
# ['Geomaterials', 'Magma Transport Phenomena', 'Molecular Dynamics', 'Volcanology']
# tHnXe84AAAAJ
# ['Geophysics', 'Seismology']
# Error Bruce Tiffney UCSB not found
# UvoDtbcAAAAJ
# ['Microbiology', 'Geochemistry', 'Oceanography']
# uLjMZtQAAAAJ
# ['Paleoclimate', 'Paleoceanography']
# Error Andy Wyss UCSB UCSB not found
# q0xdxtsAAAAJ
# ['Population Ecology', 'Disease Ecology', 'Systems Biology']
# NgJPuK8AAAAJ
# ['Biological Oceanography', 'Marine Silicon Cycling']
# lOhiBXAAAAAJ
# ['Community ecology', 'marine ecology', 'plant-herbivore interactions', 'biodiversity', 'coral reefs']
# 4Td-fJUAAAAJ
# ['oceanography', 'Biological oceanography', 'marine microbial ecology', 'biogeochemistry', 'microbial oceanography']
# Error Peter Collins UCSB UCSB not found
# wPlGMRoAAAAJ
# ['Comparative Physiology', 'Environmental and Evolutionary Physiology', 'Conservation Biology', 'Climate Change', 'Fish Physiology']
# 1Fr1vakAAAAJ
# ['Evolution', 'Ecology']
# -PWYRzIAAAAJ
# ['Global Change Biology', 'Ecological Physiology', 'Invertebrate Zoology', 'Environmental Genomics', 'Marine Ecology']
# LtUBsnwAAAAJ
# ['Ecology', 'Population Biology', 'Community Ecology', 'Marine Ecology']
# Error Debora Iglesias-Rodriguez UCSB not found
# qbamjFYAAAAJ
# ['Adaptive evolution', 'Quantitative genetics', 'Phenological responses to climate change', 'Phenotypic plasticity and G x E', 'Life histo']
# Fx4qe20AAAAJ
# ['parasite ecology', 'marine ecology', 'disease ecology', 'crustacean biology', 'biological control']
# Error Jonathan Levine UCSB not found
# GPlRHI8AAAAJ
# ['Limnology', 'Oceanography', 'Physical-Biological Coupling']
# 6OtfsT0AAAAJ
# ['Plant Ecology']
# HYXM3_sAAAAJ
# ['UC Santa Barbara']
# hcuuM8gAAAAJ
# ['Theoretical Ecology', 'Acquired Metabolic Potential', 'Bioeconomics', 'Community Ecology', 'Ecosystem Dynamics']
# l_9TshUAAAAJ
# ['Ecology', 'Environmental science']
# kztqPjYAAAAJ
# ['Macroevolution', 'Phylogenetics', 'Invertebrate Zoology', 'Bioluminescence', 'Opsin']
# GaabAg8AAAAJ
# ['Ryoko Oono']
# 5y_dK0oAAAAJ
# ['Evolution', 'population genetics', 'behavioral ecology', 'life history']
# OtbhlmIAAAAJ
# ['evolution', 'genetics', 'ecology', 'biometry', 'statistics']
# TsZjKA4AAAAJ
# ['marine microbial ecology', 'marine archaea', 'nitrogen cycling', 'oceanography']
# sFIZSUYAAAAJ
# ['Population & Community Ecology', 'Marine Ecology']
# bxbOvMgAAAAJ
# ['Adrian C. Stier']
# Error Raul Suarez UCSB not found
# t07iyOAAAAAJ
# ['herpetology', 'macroevolution']
# -JrND60AAAAJ
# ['The causes and consequences of genetic …']
# 9Jcd7mcAAAAJ
# ['Marine Microbial Ecology and Evolution']
# X-2BjW4AAAAJ
# ['conservation biology', 'ecology', 'community', 'food-web', 'disease ecology']
# qYym6p0AAAAJ
# ['plant community and ecosystem ecology']
# 072ktIQAAAAJ
# ['Aquaculture', 'Marine Ecology', 'Fisheries', 'Climate Change', 'Ecophysiology']
# uzDaznAAAAAJ
# ['soil science', 'ecology', 'arctic science', 'microbial ecology']
# Error Peter Alagona UCSB not found
# Q8pkoBAAAAAJ
# ['Local food systems', 'food & climate justice', 'diet & nutrition', 'plant breeding & crop genetic resources', 'local & scientific knowle']
# Error Summer Gray UCSB not found
# 4n0166UAAAAJ
# ['Land Systems Science', 'Environmental Economics', 'Conservation Biology', 'Remote Sensing', 'Climate Policy']
# Error David Pellow UCSB not found
# BmbVaAgAAAAJ
# ['Water', 'Energy', 'Food']
# rsyLfcEAAAAJ
# ['Simone Pulver']
# Error Susan Stonich UCSB not found
# Error Robert Wilkinson UCSB not found
# NnxLL5YAAAAJ
# ['Risk perception', 'medical anthropology', 'health inequality', 'environmental health', 'deliberation']
# _UuIymgAAAAJ
# ['Remote Sensing', 'Geomorphology', 'Water resources', 'Quaternary Geochronology']
# HCfUlVIAAAAJ
# ['climate', 'atmospheric sciences', 'meteorology']
# iZiXeBcAAAAJ
# ['Susan Cassels']
# G8HrBaYAAAAJ
# ['geomorphology', 'biogeochemistry', 'soil science']
# Error Liz Chrastil UCSB not found
# 28mqRI8AAAAJ
# ['Arctic', 'Cryosphere', 'Greenland', 'Hydrology', 'Remote sensing']
# t4-JG2IAAAAJ
# ['location modeling', 'GIScience', 'operations research', 'transportation', 'Regional Science']
# fjZMW1oAAAAJ
# ['Cartography', 'geographic information systems', 'urban modeling', 'geocomputation']
# STbfwjsAAAAJ
# ['Geographic information science', 'urban modelling and planning', 'spatial cognition']
# 1Z6XrOUAAAAJ
# ['Ocean circulation and biogeochemistry']
# Error Tommy Dickey UCSB not found
# P2YMInoAAAAJ
# ['Climate Dynamics & Polar Climate Change']
# qrDqBXEAAAAJ
# ['Sedimentology', 'Geomorphology']
# Error Catherine Gautier UCSB not found
# xdXTW7wAAAAJ
# ['Transportation Systems Modeling and …', 'Travel Behavior', 'Transportation Policy and Planning', 'Geographic Information Scie']
# 6B2Z9vAAAAAJ
# ['GIScience', 'Semantic Web', 'Geospatial Semantics', 'Spatial Data Science', 'Web Science']
# PHyhP_AAAAAJ
# ['meteorology', 'climate', 'climate change', 'predictability', 'climate variability']
# yaLhLgkAAAAJ
# ['Biogeochemistry', 'Earth System Science']
# SQsXfZAAAAAJ
# ['GIS', 'spatial information and computing', 'semantics of information', 'ontology', 'usability']
# Error Phaedon Kyriakidis UCSB not found
# WQ9iC9kAAAAJ
# ['Hydrology and Water Resources']
# w_JW40AAAAAJ
# ['population', 'health', 'environment']
# Error Joseph McFadden UCSB not found
# Error Joel Michaelsen UCSB not found
# Error Dan Montello UCSB not found
# Raj7sewAAAAJ
# ['GIScience', 'location modeling', 'spatial optimization', 'regional science', 'spatial data science']
# UmAJBOIAAAAJ
# ['Coastal oceanography', 'autonomous platforms']
# Error Martin Raubal UCSB not found
# v5VGkXMAAAAJ
# ['Remote sensing']
# i5ZL1ywAAAAJ
# ['Oceanography', 'Marine Science', 'Biogeochemistry', 'Remote Sensing', 'Spatial Ecology']
# QebCBSUAAAAJ
# ['Stuart Sweeney']
# 8PNXV2wAAAAJ
# ['Libe Washburn']
# VGaoB64AAAAJ
# ['Ecohydrology', 'Environmental Sciences', 'Ecology', 'Hydrology', 'Water Resources']
# Error Jean Carlson UCSB not found
# FjU4kL0AAAAJ
# ['renewable energy', 'solar', 'wind', 'biomass', 'policy']
# Error Chandra Krintz UCSB not found
# d3FwJjMAAAAJ
# ['anaerobic fungi', 'microbial consortia', 'bioengineering', 'sustainability', 'membrane proteins']
# vNZ4mYoAAAAJ
# ['Samantha Stevenson']

# %%
# Write PI identifiers to URLs sorted chronologically by publication date
urls = []
for element in identifier:
    if element == 'none':
        urls.append('none')
    else:
        sample_url = 'https://scholar.google.com/citations?user='+element+'&view_op=list_works&sortby=pubdate'
        urls.append(sample_url)
#print(urls)

# %%
# Clean interest keywords to remove PI name and convert list to string
keys = []
for entry in interests:
    for name in names:
        if entry[0] == name:
            print(entry[0])
            keys.append('none')
        else:
            keys.append(entry)
#print(keys)
# Out:
# Frank W Davis
# Jeff Dozier
# Roland Geyer
# Gary Libecap
# Matthew Potoski
# Galen Stucky
# Douglas Burbank
# Ryoko Oono
# Simone Pulver
# Susan Cassels
# Stuart Sweeney
# Libe Washburn
# Samantha Stevenson

# %%
# Write PI id to Scholar_Identifier column, interests to Scholar_Keywords column, and url to Scholar_Url in new csv
column_identifier = pd.Series(identifier)
column_interests = pd.Series(interests)
column_url = pd.Series(urls)
df.insert(loc=9, column='Scholar_Identifier', value=column_identifier)
df.insert(loc=10, column='Scholar_Url', value=column_url)
df.insert(loc=11, column='Scholar_Keywords', value=column_interests)
#print(df)
df.to_csv('people/PI_processed.csv')

# %%
# Get publication list (2014-2019) from a given author's url
from bs4 import BeautifulSoup
import urllib
print(urls[0])
# Out:
# https://scholar.google.com/citations?user=RCP0c0kAAAAJ&view_op=list_works&sortby=pubdate
