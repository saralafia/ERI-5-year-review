# %%
# Import libraries
import pandas as pd
import numpy as np
import glob
import os

# %%
# Read in csvs of ERI PI publications (09-14 | 14-19) from Dimensions to a single dataframe (all_data)
all_data = pd.DataFrame()
for f in glob.glob("data/publications/ERI-publications-09-14/ERI-publications/*.csv"):
    #df = pd.read_csv(f,index_col=None,skiprows=1)
    df = pd.read_csv(f,index_col=0,header=1)
    df['filename'] = os.path.basename(f)
    all_data = all_data.append(df,ignore_index=True, sort=False)
#all_data.head()
len(all_data)
# Out:
# 13383

# %%
# Subset dataframe (all_data) to only include records (2009-2014 | 2014-2019) for all PIs and return count of pubs
subset = all_data[(all_data.PubYear>=2009.0)&(all_data.PubYear<=2014.0)]
#subset.dtypes
#subset.head()
len(subset)
subset.to_csv("data/publications/ERI-publications-2009-2014_processed.csv")
# Out:
# 3192

# %%
# Load subset dataframe for all ERI (09-14 | 14-19) and subset a PI (Dave Siegel) to a new dataframe (pi_data)
subset_data_09 = pd.read_csv("data/publications/ERI-publications-2009-2014_deduplicated.csv")
#pi_data_09 = subset_data_09[(subset_data_09.filename=="David-A-Siegel.csv")]
#subset_data_14 = pd.read_csv("data/publications/ERI-publications-2014-2019_deduplicated.csv")
#pi_data_14 = subset_data_14[(subset_data_14.filename=="David-A-Siegel.xlsx")]
len(subset_data_09)
# Out:
# 3192

# %%
# Read in ERI or PI Field of Research (FOR) divisions and groups (146)
# CHANGE all_codes_ERI = accordingly for all of ERI (subset_data_09 | _14) or for specific PI (pi_data_09 |_14)
all_codes_ERI = subset_data_09['FOR (ANZSRC) Categories']
split_codes_ERI = all_codes_ERI.str.split(pat=";",expand=True).stack()
values_ERI = split_codes_ERI.value_counts().keys().tolist()
counts_ERI = split_codes_ERI.value_counts().tolist()
research_codes_ERI = pd.DataFrame(list(zip(values_ERI,counts_ERI)),columns=['Code','Count'])
research_codes_ERI['Label']=research_codes_ERI['Code'].str.extract('(\w+)', expand=True)
#research_codes_ERI['ID']=research_codes_ERI['Code'].str.extract('([^.0-9])', expand=True)
#research_codes_ERI['ID']
rc_grouped = research_codes_ERI.groupby(['Label'],as_index=False)['Count'].sum().sort_values(by=['Count'],ascending=False)
sorted_rc = research_codes_ERI.sort_values('Count',ascending=False).drop_duplicates(['Label'])
sorted_rc.head()
#sorted_rc.to_csv('publications/ERI-publications-FOR-codes.csv')
#sorted_rc.shape
# Out:
#                                                 Code  Count Label
# 0                                       0602 Ecology    466  0602
# 1                                       0403 Geology    305  0403
# 2          0502 Environmental Science and Management    251  0502
# 3  0406 Physical Geography and Environmental Geos...    229  0406
# 4                          0909 Geomatic Engineering    154  0909

# %%
# Split ERI FOR codes into divisions and groups ('division','group','label','count')
# CHANGE filename of treemap file accordingly when saving out csv file
new_codes = pd.DataFrame(columns=['division','group','label','count'])
new_codes['label'] = sorted_rc['Label'].astype('int64')

def catdiv(c):
    if (((c['label'] >= 100) & (c['label'] <= 199)) | (c['label'] == 1)):
        return 'Mathematical Sciences'
    elif (((c['label'] >= 200) & (c['label'] <= 299)) | (c['label'] == 2)):
        return 'Physical Sciences'
    elif (((c['label'] >= 300) & (c['label'] <= 399)) | (c['label'] == 3)):
        return 'Chemical Sciences'
    elif (((c['label'] >= 400) & (c['label'] <= 499)) | (c['label'] == 4)):
        return 'Earth Sciences'
    elif (((c['label'] >= 500) & (c['label'] <= 599)) | (c['label'] == 5)):
        return 'Environmental Sciences'
    elif ((c['label'] >= 600) & (c['label'] <= 699)) | (c['label'] == 6):
        return 'Biological Sciences'
    elif (((c['label'] >= 700) & (c['label'] <= 799)) | (c['label'] == 7)):
        return 'Agricultural and Veterinary Sciences'
    elif (((c['label'] >= 800) & (c['label'] <= 899)) | (c['label'] == 8)):
        return 'Information and Computing Sciences'
    elif (((c['label'] >= 900) & (c['label'] <= 999)) | (c['label'] == 9)):
        return 'Engineering'
    elif (((c['label'] >= 1000) & (c['label'] <= 1099)) | (c['label'] == 10)):
        return 'Technology'
    elif (((c['label'] >= 1100) & (c['label'] <= 1199)) | (c['label'] == 11)):
        return 'Medical and Health Sciences'
    elif (((c['label'] >= 1200) & (c['label'] <= 1299)) | (c['label'] == 12)):
        return 'Built Environment and Design'
    elif (((c['label'] >= 1300) & (c['label'] <= 1399)) | (c['label'] == 13)):
        return 'Education'
    elif (((c['label'] >= 1400) & (c['label'] <= 1499)) | (c['label'] == 14)):
        return 'Economics'
    elif (((c['label'] >= 1500) & (c['label'] <= 1599)) | (c['label'] == 15)):
        return 'Commerce, Management, Tourism and Services'
    elif (((c['label'] >= 1600) & (c['label'] <= 1699)) | (c['label'] == 16)):
        return 'Studies in Human Society'
    elif (((c['label'] >= 1700) & (c['label'] <= 1799)) | (c['label'] == 17)):
        return 'Psychology and Cognitive Sciences'
    elif (((c['label'] >= 1800) & (c['label'] <= 1899)) | (c['label'] == 18)):
        return 'Law and Legal Studies'
    elif (((c['label'] >= 1900) & (c['label'] <= 1999)) | (c['label'] == 19)):
        return 'Studies in Creative Arts and Writing'
    elif (((c['label'] >= 2000) & (c['label'] <= 2099)) | (c['label'] == 20)):
        return 'Language, Communication, and Culture'
    elif (((c['label'] >= 2100) & (c['label'] <= 2199)) | (c['label'] == 21)):
        return 'History and Archaeology'
    elif (((c['label'] >= 2200) & (c['label'] <= 2299)) | (c['label'] == 22)):
        return 'Philosophy and Religious Studies'
    else:
        return 'Undefined'

def catgrp(x):
    if ((x['label'] >= 1) & (x['label'] <= 22)):
        return 'Undefined'
    else:
        return sorted_rc['Code']

new_codes['division'] = new_codes.apply(catdiv, axis=1)
new_codes['group'] = sorted_rc['Code']
new_codes['count'] = sorted_rc['Count']
new_codes.sort_values('group')
#new_codes.shape
new_codes.to_csv("data/publications/ERI-publications-2009-2014-treemap-deduplicated.csv")
#filtered_codes = new_codes['label']> 22
#filtered_codes = new_codes['count']> 1
#new_codes['count'] = new_codes[filtered_codes]
new_codes.head()
#new_codes_filtered.sort_values('label')
# Out:
#                  division                                              group  \
# 0     Biological Sciences                                       0602 Ecology
# 1          Earth Sciences                                       0403 Geology
# 2  Environmental Sciences          0502 Environmental Science and Management
# 3          Earth Sciences  0406 Physical Geography and Environmental Geos...
# 4             Engineering                          0909 Geomatic Engineering
#
#    label  count
# 0    602    466
# 1    403    305
# 2    502    251
# 3    406    229
# 4    909    154

# %%
# Create a dataframe merging both review periods by an outer join on labels field (NA is 0 if FOR code missing)
all_data_09 = pd.read_csv("data/publications/ERI-publications-2009-2014-treemap-deduplicated.csv",index_col=0)
all_data_14 = pd.read_csv("data/publications/ERI-publications-2014-2019-treemap-deduplicated.csv",index_col=0)
merge_all_data = pd.merge(all_data_14,all_data_09[['label','count']],on='label',how='outer',suffixes=('_14_19','_09_14'))
merge_all_data['count_14_19'].fillna(0, inplace=True)
merge_all_data['count_09_14'].fillna(0, inplace=True)
merge_all_data['difference'] = merge_all_data['count_14_19'] - merge_all_data['count_09_14']
sum_09 = merge_all_data['count_09_14'].sum()
sum_14 = merge_all_data['count_14_19'].sum()
merge_all_data['norm_09_14'] = merge_all_data['count_09_14'] / sum_09
merge_all_data['norm_14_19'] = merge_all_data['count_14_19'] / sum_14
merge_all_data['norm_diff'] = merge_all_data['norm_14_19'] - merge_all_data['norm_09_14']
merge_all_data.to_csv("data/publications/ERI-publications-2019-2009-difference-treemap-deduplicated.csv")
merge_all_data
# Out:
#                                        division  \
# 0                           Biological Sciences
# 1                        Environmental Sciences
# 2                                Earth Sciences
# 3                                Earth Sciences
# 4                                   Engineering
# 5                                Earth Sciences
# 6                                Earth Sciences
# 7                           Biological Sciences
# 8                                   Engineering
# 9                        Environmental Sciences
# 10                                  Engineering
# 11                          Biological Sciences
# 12                          Biological Sciences
# 13                               Earth Sciences
# 14                          Biological Sciences
# 15                          Biological Sciences
# 16                               Earth Sciences
# 17           Information and Computing Sciences
# 18                       Environmental Sciences
# 19                                    Economics
# 20           Information and Computing Sciences
# 21                     Studies in Human Society
# 22                  Medical and Health Sciences
# 23                       Environmental Sciences
# 24                 Built Environment and Design
# 25                          Biological Sciences
# 26                               Earth Sciences
# 27                                  Engineering
# 28                            Chemical Sciences
# 29         Agricultural and Veterinary Sciences
# ..                                          ...
# 101                    Studies in Human Society
# 102  Commerce, Management, Tourism and Services
# 103        Language, Communication, and Culture
# 104          Information and Computing Sciences
# 105                Built Environment and Design
# 106            Philosophy and Religious Studies
# 107                 Medical and Health Sciences
# 108                    Studies in Human Society
# 109                           Chemical Sciences
# 110            Philosophy and Religious Studies
# 111                                 Engineering
# 112                     History and Archaeology
# 113                                   Education
# 114                           Chemical Sciences
# 115                    Studies in Human Society
# 116                 Medical and Health Sciences
# 117            Philosophy and Religious Studies
# 118                                  Technology
# 119                 Medical and Health Sciences
# 120                     History and Archaeology
# 121            Philosophy and Religious Studies
# 122        Language, Communication, and Culture
# 123        Agricultural and Veterinary Sciences
# 124                 Medical and Health Sciences
# 125                      Environmental Sciences
# 126                                  Technology
# 127                                         NaN
# 128                                         NaN
# 129                                         NaN
# 130                                         NaN
#
#                                                  group  label  count_14_19  \
# 0                                         0602 Ecology    602        857.0
# 1            0502 Environmental Science and Management    502        515.0
# 2                                         0403 Geology    403        455.0
# 3    0406 Physical Geography and Environmental Geos...    406        382.0
# 4                            0909 Geomatic Engineering    909        297.0
# 5                                    0402 Geochemistry    402        181.0
# 6                                    0405 Oceanography    405        175.0
# 7                                        0604 Genetics    604        150.0
# 8                               0905 Civil Engineering    905        136.0
# 9                         0501 Ecological Applications    501        130.0
# 10                      0907 Environmental Engineering    907        116.0
# 11                              06 Biological Sciences      6        106.0
# 12                                   0605 Microbiology    605        105.0
# 13                           0401 Atmospheric Sciences    401         99.0
# 14                           0603 Evolutionary Biology    603         99.0
# 15                                  0607 Plant Biology    607         99.0
# 16                                     0404 Geophysics    404         96.0
# 17   0801 Artificial Intelligence and Image Processing    801         96.0
# 18                                  0503 Soil Sciences    503         86.0
# 19                              1402 Applied Economics   1402         83.0
# 20                            0806 Information Systems    806         77.0
# 21                                1604 Human Geography   1604         64.0
# 22              1117 Public Health and Health Services   1117         55.0
# 23                           05 Environmental Sciences      5         52.0
# 24                    1205 Urban and Regional Planning   1205         46.0
# 25                      0699 Other Biological Sciences    699         41.0
# 26                                   04 Earth Sciences      4         40.0
# 27                  0915 Interdisciplinary Engineering    915         38.0
# 28          0306 Physical Chemistry (incl. Structural)    306         38.0
# 29             07 Agricultural and Veterinary Sciences      7         36.0
# ..                                                 ...    ...          ...
# 101                                    1603 Demography   1603          2.0
# 102                                       1506 Tourism   1506          2.0
# 103                              2002 Cultural Studies   2002          2.0
# 104            0802 Computation Theory and Mathematics    802          2.0
# 105                                  1201 Architecture   1201          2.0
# 106     2202 History and Philosophy of Specific Fields   2202          2.0
# 107                                    1107 Immunology   1107          2.0
# 108                                   1607 Social Work   1607          2.0
# 109          0304 Medicinal and Biomolecular Chemistry    304          1.0
# 110                2204 Religion and Religious Studies   2204          1.0
# 111                                 0908 Food Sciences    908          1.0
# 112                2102 Curatorial and Related Studies   2102          1.0
# 113                       1302 Curriculum and Pedagogy   1302          1.0
# 114                             0305 Organic Chemistry    305          1.0
# 115                1699 Other Studies In Human Society   1699          1.0
# 116         1114 Paediatrics and Reproductive Medicine   1114          1.0
# 117                                    2203 Philosophy   2203          1.0
# 118                                      10 Technology     10          1.0
# 119    1102 Cardiorespiratory Medicine and Haematology   1102          1.0
# 120                            2103 Historical Studies   2103          1.0
# 121                22 Philosophy and Religious Studies     22          1.0
# 122                              2005 Literary Studies   2005          1.0
# 123                      0706 Horticultural Production    706          1.0
# 124      1115 Pharmacology and Pharmaceutical Sciences   1115          1.0
# 125                  0599 Other Environmental Sciences    599          1.0
# 126                    1001 Agricultural Biotechnology   1001          1.0
# 127                                                NaN    204          0.0
# 128                                                NaN    101          0.0
# 129                                                NaN   1004          0.0
# 130                                                NaN   1101          0.0
#
#      count_09_14  difference  norm_09_14  norm_14_19  norm_diff
# 0          466.0       391.0    0.127671    0.154026   0.026355
# 1          251.0       264.0    0.068767    0.092559   0.023792
# 2          305.0       150.0    0.083562    0.081776  -0.001786
# 3          229.0       153.0    0.062740    0.068656   0.005916
# 4          154.0       143.0    0.042192    0.053379   0.011187
# 5          107.0        74.0    0.029315    0.032531   0.003215
# 6          126.0        49.0    0.034521    0.031452  -0.003068
# 7           28.0       122.0    0.007671    0.026959   0.019288
# 8           32.0       104.0    0.008767    0.024443   0.015676
# 9           63.0        67.0    0.017260    0.023364   0.006104
# 10          59.0        57.0    0.016164    0.020848   0.004684
# 11          90.0        16.0    0.024658    0.019051  -0.005606
# 12          67.0        38.0    0.018356    0.018871   0.000515
# 13          61.0        38.0    0.016712    0.017793   0.001081
# 14          18.0        81.0    0.004932    0.017793   0.012861
# 15          51.0        48.0    0.013973    0.017793   0.003820
# 16          44.0        52.0    0.012055    0.017254   0.005199
# 17          44.0        52.0    0.012055    0.017254   0.005199
# 18          68.0        18.0    0.018630    0.015457  -0.003174
# 19          52.0        31.0    0.014247    0.014917   0.000671
# 20          42.0        35.0    0.011507    0.013839   0.002332
# 21          29.0        35.0    0.007945    0.011503   0.003557
# 22          21.0        34.0    0.005753    0.009885   0.004132
# 23          30.0        22.0    0.008219    0.009346   0.001127
# 24          10.0        36.0    0.002740    0.008267   0.005528
# 25          21.0        20.0    0.005753    0.007369   0.001615
# 26          34.0         6.0    0.009315    0.007189  -0.002126
# 27          33.0         5.0    0.009041    0.006830  -0.002211
# 28         154.0      -116.0    0.042192    0.006830  -0.035362
# 29          21.0        15.0    0.005753    0.006470   0.000717
# ..           ...         ...         ...         ...        ...
# 101          3.0        -1.0    0.000822    0.000359  -0.000462
# 102          2.0         0.0    0.000548    0.000359  -0.000188
# 103          0.0         2.0    0.000000    0.000359   0.000359
# 104          1.0         1.0    0.000274    0.000359   0.000085
# 105          0.0         2.0    0.000000    0.000359   0.000359
# 106          0.0         2.0    0.000000    0.000359   0.000359
# 107          2.0         0.0    0.000548    0.000359  -0.000188
# 108          1.0         1.0    0.000274    0.000359   0.000085
# 109          1.0         0.0    0.000274    0.000180  -0.000094
# 110          0.0         1.0    0.000000    0.000180   0.000180
# 111          0.0         1.0    0.000000    0.000180   0.000180
# 112          2.0        -1.0    0.000548    0.000180  -0.000368
# 113          2.0        -1.0    0.000548    0.000180  -0.000368
# 114          9.0        -8.0    0.002466    0.000180  -0.002286
# 115          0.0         1.0    0.000000    0.000180   0.000180
# 116          0.0         1.0    0.000000    0.000180   0.000180
# 117          0.0         1.0    0.000000    0.000180   0.000180
# 118          6.0        -5.0    0.001644    0.000180  -0.001464
# 119          1.0         0.0    0.000274    0.000180  -0.000094
# 120          3.0        -2.0    0.000822    0.000180  -0.000642
# 121          0.0         1.0    0.000000    0.000180   0.000180
# 122          0.0         1.0    0.000000    0.000180   0.000180
# 123          0.0         1.0    0.000000    0.000180   0.000180
# 124          1.0         0.0    0.000274    0.000180  -0.000094
# 125          0.0         1.0    0.000000    0.000180   0.000180
# 126          2.0        -1.0    0.000548    0.000180  -0.000368
# 127          7.0        -7.0    0.001918    0.000000  -0.001918
# 128          3.0        -3.0    0.000822    0.000000  -0.000822
# 129          2.0        -2.0    0.000548    0.000000  -0.000548
# 130          1.0        -1.0    0.000274    0.000000  -0.000274
#
# [131 rows x 9 columns]
