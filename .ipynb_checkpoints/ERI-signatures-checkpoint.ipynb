# %%
# Load libraries 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Load csv of publication FOR codes (09-14 | 14-19)
new_codes = pd.read_csv("data/publications/ERI-publications-2009-2014-treemap.csv")
new_codes.head()
# Out:
#    Unnamed: 0                division  \
# 0           0     Biological Sciences
# 1           1          Earth Sciences
# 2           3          Earth Sciences
# 3           4  Environmental Sciences
# 4           5             Engineering
#
#                                         group  label  count
# 0                      06 Biological Sciences      6    772
# 1                           04 Earth Sciences      4    540
# 2                                0403 Geology    403    429
# 3   0502 Environmental Science and Management    502    348
# 4                              09 Engineering      9    344

# %%
# New summarized dataframe of ERI's FOR codes (09-14 | 24-19) by division
eriDivisions = new_codes.groupby(['division'],as_index=False)['count'].sum()
eriDivisions.sort_values('count',ascending=False)
# Out:
#                                       division  count
# 5                               Earth Sciences   1702
# 1                          Biological Sciences   1359
# 8                                  Engineering    794
# 9                       Environmental Sciences    765
# 3                            Chemical Sciences    616
# 16                           Physical Sciences    294
# 11          Information and Computing Sciences    254
# 18                    Studies in Human Society    165
# 6                                    Economics    145
# 0         Agricultural and Veterinary Sciences    106
# 19                                  Technology     71
# 15                 Medical and Health Sciences     70
# 14                       Mathematical Sciences     54
# 17           Psychology and Cognitive Sciences     51
# 2                 Built Environment and Design     28
# 10                     History and Archaeology     22
# 4   Commerce, Management, Tourism and Services     12
# 13                       Law and Legal Studies     10
# 7                                    Education      8
# 12        Language, Communication, and Culture      4

# %%
# New summarized dataframe of ERI's FOR codes (09-14 | 24-19) by group
eriGroups = new_codes.groupby(['group'],as_index=False)['count'].sum()
eriGroups.sort_values('count',ascending=False)
# Out:
#                                                  group  count
# 22                              06 Biological Sciences    772
# 78                                   04 Earth Sciences    540
# 15                                        0403 Geology    429
# 21           0502 Environmental Science and Management    348
# 91                                      09 Engineering    344
# 82                                        0602 Ecology    341
# 19                           05 Environmental Sciences    298
# 75                                03 Chemical Sciences    249
# 17                                   0405 Oceanography    234
# 79   0406 Physical Geography and Environmental Geos...    220
# 11          0306 Physical Chemistry (incl. Structural)    199
# 38                           0909 Geomatic Engineering    173
# 3                                 02 Physical Sciences    142
# 14                                   0402 Geochemistry    125
# 90               08 Information and Computing Sciences    118
# 37                      0907 Environmental Engineering    106
# 53                                        14 Economics     88
# 13                           0401 Atmospheric Sciences     84
# 26             07 Agricultural and Veterinary Sciences     73
# 32                            0806 Information Systems     71
# 16                                     0404 Geophysics     67
# 58                         16 Studies in Human Society     65
# 84                                   0605 Microbiology     64
# 20                        0501 Ecological Applications     64
# 72                0201 Astronomical and Space Sciences     60
# 80                                  0503 Soil Sciences     55
# 93                          0912 Materials Engineering     54
# 8                             0302 Inorganic Chemistry     53
# 86                                  0607 Plant Biology     51
# 28    0801 Artificial Intelligence and Image Proces...     51
# ..                                                 ...    ...
# 57            1507 Transportation and Freight Services      3
# 71        0103 Numerical and Computational Mathematics      3
# 1                                0101 Pure Mathematics      3
# 18                           0499 Other Earth Sciences      3
# 70                            0102 Applied Mathematics      3
# 115                            2103 Historical Studies      3
# 56                                        1506 Tourism      2
# 103                       1302 Curriculum and Pedagogy      2
# 114                2102 Curatorial and Related Studies      2
# 113                                   2004 Linguistics      2
# 42                          1004 Medical Biotechnology      2
# 108                                     1505 Marketing      2
# 67              20 Language, Communication and Culture      2
# 106                                  1403 Econometrics      2
# 47                                     1107 Immunology      2
# 54                                1401 Economic Theory      2
# 104               1303 Specialist Studies In Education      2
# 100                                 1109 Neurosciences      2
# 29             0802 Computation Theory and Mathematics      2
# 96                     1001 Agricultural Biotechnology      2
# 5                               0203 Classical Physics      2
# 89     0799 Other Agricultural and Veterinary Sciences      1
# 101                   1113 Ophthalmology and Optometry      1
# 98     1102 Cardiorespiratory Medicine and Haematology      1
# 63                                    1607 Social Work      1
# 45          1101 Medical Biochemistry and Metabolomics      1
# 39                      0910 Manufacturing Engineering      1
# 10           0304 Medicinal and Biomolecular Chemistry      1
# 85                                     0606 Physiology      1
# 48       1115 Pharmacology and Pharmaceutical Sciences      1
#
# [116 rows x 2 columns]

# %%
# Plot bar chart to see FOR divisions for all of ERI (09-14 | 14-19)
# CHANGE labels and filename to reflect years and ERI | PI
plt.style.use('ggplot')
x_pos = [i for i, _ in enumerate(eriDivisions['division'])]
plt.bar(x_pos, eriDivisions['count'], color='teal')
plt.xlabel("FOR division")
plt.ylabel("count (by publication)")
plt.title("ERI Field of Research Divisions (2009-2014)")
plt.xticks(x_pos)
plt.savefig('figures/ERI_FOR_divisions_bar_2009_2014.png', dpi=200)
plt.show()
plt.draw()

# %%
# Plot bar chart to see FOR groups for all of ERI (09-14 | 14-19)
# CHANGE labels and filename to reflect years and ERI | PI
plt.style.use('ggplot')
x_pos = [i for i, _ in enumerate(eriGroups['group'])]
plt.bar(x_pos, eriGroups['count'], color='orange')
plt.xlabel("FOR group")
plt.ylabel("count (by publication)")
plt.title("ERI Field of Research Groups (2009-2014)")
plt.xticks(x_pos)
plt.savefig('figures/ERI_FOR_groups_bar_2009_2014.png', dpi=200)
plt.show()
plt.draw()
